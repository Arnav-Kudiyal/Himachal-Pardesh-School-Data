# %%
import pandas as pd

# %%
data = pd.read_csv("data2025.csv")

# %%
data.head()
# Out:
#   Total\nSr.N0. Total\nSr.N0..1 Total\nSr.N0..2 Total\nSr.N0..3  \
# 0             1               1            1113           11501
# 1             2               2            1002           11502
# 2             3               3            1107           11505
# 3             4               4            1135           11506
# 4             5               5            1117           11507
#
#                       Total\nSr.N0..4 Total\nSr.N0..5 Total\nSr.N0..6  \
# 0               CAMBRIDGE HIGH SCHOOL          JEJWIN        BILASPUR
# 1               SARSWATI VIDYA MANDIR           AUHAR        BILASPUR
# 2  SARSWATI VIDYA MANDIR\nHIGH SCHOOL          HATWAR        BILASPUR
# 3             NAV LOK ADARSH VIDYALYA        KHANSARA        BILASPUR
# 4           ALPHA PUBLIC HIGH\nSCHOOL       JHANDUTTA        BILASPUR
#
#   Total\nSr.N0..7 Total\nSr.N0..8 Total\nSr.N0..9 Total\nSr.N0..10  \
# 0          174017        9th-10th             NaN          2025-26
# 1          174024   9th-10th (C )             NaN          2025-26
# 2          174028   9th-10th (C )             NaN          2025-26
# 3          174026   9th-10th (C )             NaN          2025-26
# 4          174031   9th-10th (C )             NaN          2025-26
#
#                          Total\nSr.N0..11             Total\nSr.N0..12
# 0                             94188-71427    pardeepdhiman96@gmail.com
# 1                 94599-24008,98171-44320          svmauhar9@gmail.com
# 2  88946-58735,94592-\n97036,01978-252930      svmhatwar1950@gmail.com
# 3   94180-49929,94184-\n45064,70188-75830        navalok1993@gmail.com
# 4                             96255-37444  alphaphsjhandutta@gmail.com

# %%
data.columns = [
    "Sr.No",
    "S.Wise",
    "School_Code",
    "Affiliation_Code",
    "Name_of_the_Institute",
    "Station",
    "District",
    "PIN",
    "Class",
    "Temporary",
    "Session",
    "Contact_No",
    "Email"
]

# %%
data.head()
# Out:
#   Sr.No S.Wise School_Code Affiliation_Code  \
# 0     1      1        1113            11501
# 1     2      2        1002            11502
# 2     3      3        1107            11505
# 3     4      4        1135            11506
# 4     5      5        1117            11507
#
#                 Name_of_the_Institute    Station  District     PIN  \
# 0               CAMBRIDGE HIGH SCHOOL     JEJWIN  BILASPUR  174017
# 1               SARSWATI VIDYA MANDIR      AUHAR  BILASPUR  174024
# 2  SARSWATI VIDYA MANDIR\nHIGH SCHOOL     HATWAR  BILASPUR  174028
# 3             NAV LOK ADARSH VIDYALYA   KHANSARA  BILASPUR  174026
# 4           ALPHA PUBLIC HIGH\nSCHOOL  JHANDUTTA  BILASPUR  174031
#
#            Class Temporary  Session                              Contact_No  \
# 0       9th-10th       NaN  2025-26                             94188-71427
# 1  9th-10th (C )       NaN  2025-26                 94599-24008,98171-44320
# 2  9th-10th (C )       NaN  2025-26  88946-58735,94592-\n97036,01978-252930
# 3  9th-10th (C )       NaN  2025-26   94180-49929,94184-\n45064,70188-75830
# 4  9th-10th (C )       NaN  2025-26                             96255-37444
#
#                          Email
# 0    pardeepdhiman96@gmail.com
# 1          svmauhar9@gmail.com
# 2      svmhatwar1950@gmail.com
# 3        navalok1993@gmail.com
# 4  alphaphsjhandutta@gmail.com

# %%
data = data.drop(index=0)

# %%
data.head()
# Out:
#   Sr.No S.Wise School_Code Affiliation_Code  \
# 1     2      2        1002            11502
# 2     3      3        1107            11505
# 3     4      4        1135            11506
# 4     5      5        1117            11507
# 5     6      6        1188            11509
#
#                 Name_of_the_Institute    Station  District     PIN  \
# 1               SARSWATI VIDYA MANDIR      AUHAR  BILASPUR  174024
# 2  SARSWATI VIDYA MANDIR\nHIGH SCHOOL     HATWAR  BILASPUR  174028
# 3             NAV LOK ADARSH VIDYALYA   KHANSARA  BILASPUR  174026
# 4           ALPHA PUBLIC HIGH\nSCHOOL  JHANDUTTA  BILASPUR  174031
# 5  SARSWATI VIDYA MANDIR\nHIGH SCHOOL  RISHIKESH  BILASPUR  174024
#
#            Class Temporary  Session                              Contact_No  \
# 1  9th-10th (C )       NaN  2025-26                 94599-24008,98171-44320
# 2  9th-10th (C )       NaN  2025-26  88946-58735,94592-\n97036,01978-252930
# 3  9th-10th (C )       NaN  2025-26   94180-49929,94184-\n45064,70188-75830
# 4  9th-10th (C )       NaN  2025-26                             96255-37444
# 5       9th-10th       NaN  2025-26                94182-56176, 98166-09114
#
#                          Email
# 1          svmauhar9@gmail.com
# 2      svmhatwar1950@gmail.com
# 3        navalok1993@gmail.com
# 4  alphaphsjhandutta@gmail.com
# 5   svmrishikesh1986@gmail.com

# %%
data = data.drop(columns=["S.Wise","Temporary", "Session"])

# %%
data.head()
# Out:
#   Sr.No School_Code Affiliation_Code               Name_of_the_Institute  \
# 1     2        1002            11502               SARSWATI VIDYA MANDIR
# 2     3        1107            11505  SARSWATI VIDYA MANDIR\nHIGH SCHOOL
# 3     4        1135            11506             NAV LOK ADARSH VIDYALYA
# 4     5        1117            11507           ALPHA PUBLIC HIGH\nSCHOOL
# 5     6        1188            11509  SARSWATI VIDYA MANDIR\nHIGH SCHOOL
#
#      Station  District     PIN          Class  \
# 1      AUHAR  BILASPUR  174024  9th-10th (C )
# 2     HATWAR  BILASPUR  174028  9th-10th (C )
# 3   KHANSARA  BILASPUR  174026  9th-10th (C )
# 4  JHANDUTTA  BILASPUR  174031  9th-10th (C )
# 5  RISHIKESH  BILASPUR  174024       9th-10th
#
#                                Contact_No                        Email
# 1                 94599-24008,98171-44320          svmauhar9@gmail.com
# 2  88946-58735,94592-\n97036,01978-252930      svmhatwar1950@gmail.com
# 3   94180-49929,94184-\n45064,70188-75830        navalok1993@gmail.com
# 4                             96255-37444  alphaphsjhandutta@gmail.com
# 5                94182-56176, 98166-09114   svmrishikesh1986@gmail.com

# %%
data["Class"].value_counts()
# Out:
# Class
# 9th-10th                                         408
# 9th-10th (C )                                    130
# 9th-10th (c )                                     71
# 9th-+2(Arts/Sci/Comm)                             49
# 9th-10th  (C )                                    24
#                                                 ...
# 9th-+2(Arts/Sci/Com.)                              1
# 9th-+2(Sci) )                                      1
# 11th-12th (Arts/Sci/Comm)\n)                       1
# 9th-+2  (Arts/Comm)                                1
# 9th-10th Permanent &11th-\n12th (Sci) Renewal      1
# Name: count, Length: 207, dtype: int64

# %%
data.shape
# Out:
# (1179, 10)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1179 entries, 1 to 1179
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Sr.No                  1179 non-null   object
#  1   School_Code            1176 non-null   object
#  2   Affiliation_Code       1167 non-null   object
#  3   Name_of_the_Institute  1176 non-null   object
#  4   Station                1176 non-null   object
#  5   District               1176 non-null   object
#  6   PIN                    1173 non-null   object
#  7   Class                  1176 non-null   object
#  8   Contact_No             1174 non-null   object
#  9   Email                  1167 non-null   object
# dtypes: object(10)
# memory usage: 92.2+ KB

# %%
data = data[data["Class"].str.strip().str.lower() != "9th-10th"]

# %%
data = data[data["Class"].str.strip().str.lower() != "9th-10th (C )"]

# %%
data = data[data["Class"].str.strip().str.lower() != "9th-10th (c )"]

# %%
data = data[data["Class"].str.strip().str.lower() != "9th-10th  (C )"]

# %%
data = data[data["Class"].str.strip().str.lower() != "9th-+2(Arts)"]

# %%
data = data[data["Class"].str.strip().str.lower() != "9th - 10th"]

# %%
data.head()
# Out:
#    Sr.No School_Code Affiliation_Code           Name_of_the_Institute  \
# 37    38        1044            11703             ARYAN PUBLIC SCHOOL
# 38    39        1045            11706  CRESCENT PUBLIC\nSR.SEC.SCHOOL
# 39    40        1099            11707          MINERVA SR.SEC. SCHOOL
# 40    41        1100            11708           VISION CONVENT SCHOOL
# 42    43        1028            11711     JYOTI PUBLIC\nSR.SEC.SCHOOL
#
#       Station  District     PIN                  Class  \
# 37   BILASPUR  BILASPUR  174001           9th-+2(Sci.)
# 38   BILASPUR  BILASPUR  174001      9th-+2(Sci.) (c )
# 39  GHUMARWIN  BILASPUR  174021      9th-+2(Sci.) (c )
# 40  GHUMARWIN  BILASPUR  174021  9th-+2(Arts/Sci/Comm)
# 42    BERTHIN  BILASPUR  174029     9th-+2(Sci.)  (c )
#
#                                  Contact_No                          Email
# 37  01978-221863, 98172-00073,\n94181-07622    Principalaryanblp@yahoo.com
# 38   98173-57901,01978-221660,\n94180-41606               cpsblp@gmail.com
# 39                94182-12885, 01978-255616          parvesh3791@gmail.com
# 40                94180-12324, 01978-256789  visionconventschool@gmail.com
# 42                            , 82191-76165        Jyotischool94@gmail.com

# %%
data.shape
# Out:
# (544, 10)

# %%
data = data[data["Class"].str.strip().str.lower() != "9th-10th )"]

# %%
data = data[data["Class"].str.strip().str.lower() != "9th - 10th (c )"]

# %%
data["District"].value_counts()
# Out:
# District
# KANGRA      127
# MANDI        94
# HAMIRPUR     63
# SHIMLA       48
# SOLAN        40
# UNA          35
# KULLU        34
# BILASPUR     32
# SIRMOUR      25
# CHAMBA       21
# KINNAUR       7
# DISTRICT      3
# Name: count, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 532 entries, 37 to 1179
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Sr.No                  532 non-null    object
#  1   School_Code            529 non-null    object
#  2   Affiliation_Code       527 non-null    object
#  3   Name_of_the_Institute  529 non-null    object
#  4   Station                529 non-null    object
#  5   District               529 non-null    object
#  6   PIN                    528 non-null    object
#  7   Class                  529 non-null    object
#  8   Contact_No             528 non-null    object
#  9   Email                  524 non-null    object
# dtypes: object(10)
# memory usage: 45.7+ KB

# %%
data.head()
# Out:
#    Sr.No School_Code Affiliation_Code           Name_of_the_Institute  \
# 37    38        1044            11703             ARYAN PUBLIC SCHOOL
# 38    39        1045            11706  CRESCENT PUBLIC\nSR.SEC.SCHOOL
# 39    40        1099            11707          MINERVA SR.SEC. SCHOOL
# 40    41        1100            11708           VISION CONVENT SCHOOL
# 42    43        1028            11711     JYOTI PUBLIC\nSR.SEC.SCHOOL
#
#       Station  District     PIN                  Class  \
# 37   BILASPUR  BILASPUR  174001           9th-+2(Sci.)
# 38   BILASPUR  BILASPUR  174001      9th-+2(Sci.) (c )
# 39  GHUMARWIN  BILASPUR  174021      9th-+2(Sci.) (c )
# 40  GHUMARWIN  BILASPUR  174021  9th-+2(Arts/Sci/Comm)
# 42    BERTHIN  BILASPUR  174029     9th-+2(Sci.)  (c )
#
#                                  Contact_No                          Email
# 37  01978-221863, 98172-00073,\n94181-07622    Principalaryanblp@yahoo.com
# 38   98173-57901,01978-221660,\n94180-41606               cpsblp@gmail.com
# 39                94182-12885, 01978-255616          parvesh3791@gmail.com
# 40                94180-12324, 01978-256789  visionconventschool@gmail.com
# 42                            , 82191-76165        Jyotischool94@gmail.com

# %%
Kangra = data[data["District"]=="KANGRA"]

# %%
Kangra.head()
# Out:
#     Sr.No School_Code Affiliation_Code  \
# 374   375        1914            17001
# 375   376        1769            17002
# 376   377        1767            17003
# 378   379        2362            17008
# 379   380        1789            17009
#
#                          Name_of_the_Institute   Station District     PIN  \
# 374                SMT. I.G.M.P\nSR.SEC.SCHOOL     DEHRA   KANGRA  177101
# 375              GURUKUL PUBLIC\nSR.SEC.SCHOOL  BAIJNATH   KANGRA  176125
# 376  AMBIKA PUBLIC SR.SEC.SCHOOL GANESH\nBAZAR  BAIJNATH   KANGRA  176125
# 378         HANS RAJ MEMO.MODEL\nSR.SEC.SCHOOL     REHAN   KANGRA  176022
# 379               MODREN PUBLIC\nSR.SEC.SCHOOL    BANURI   KANGRA  176061
#
#                      Class                 Contact_No  \
# 374  9th-+2(Arts/Sci/Comm)   01970-233434,98164-68746
# 375  9th-+2(Arts/Sci/Comm)  01894-262882, 94180-56446
# 376      9th-+2(Arts/Comm)   01894-263756,94183-55058
# 378  9th-+2(Arts/Sci/Comm)  01893-252469, 94184-92469
# 379      9th-+2(Arts/Comm)  01894-233055,98163-81573,
#
#                              Email
# 374      igmpdchooldhera@gmail.com
# 375  principal.gurukul93@gmail.com
# 376         aps.baijnath@gmail.com
# 378           ramverma41@gmail.com
# 379            mpsbanuri@gmail.com

# %%
Kangra.shape
# Out:
# (127, 10)

# %%
mandi = data[data["District"]=="MANDI"]

# %%
hamirpur = data[data["District"]=="HAMIRPUR"]

# %%
shimla = data[data["District"]=="SHIMLA"]

# %%
solan= data[data["District"]=="SOLAN"]

# %%
una = data[data["District"]=="UNA"]

# %%
kullu = data[data["District"]=="KULLU"]

# %%
bilaspur = data[data["District"]=="BILASPUR"]

# %%
sirmour = data[data["District"]=="SIRMOUR"]

# %%
chamba = data[data["District"]=="CHAMBA"]

# %%
Kangra.to_excel("Kangra.xlsx", index=False)

# %%
mandi.to_excel("mandi.xlsx", index=False)
hamirpur.to_excel("hamirpur.xlsx", index=False)
shimla.to_excel("shimla.xlsx", index=False)
solan.to_excel("solan.xlsx", index=False)
una.to_excel("una.xlsx", index=False)
kullu.to_excel("kullu.xlsx", index=False)
bilaspur.to_excel("bilaspur.xlsx", index=False)
sirmour.to_excel("sirmour.xlsx", index=False)
chamba.to_excel("chamba.xlsx", index=False)
